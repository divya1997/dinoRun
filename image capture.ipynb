# %% [markdown]
# ### To take screenshot of dino game.

# %%
import pyautogui
#import pyscreenshot as ImageGrab
import time

# %%
time.sleep(5)
im_1 = pyautogui.screenshot(region=(12, 155, 762, 230))
#im_2 = np.array(pyautogui.screenshot(region=(363, 359, 927, 468)))
#print (im_1.size)
#print (type(im_1))
#plt.imshow(im_1, interpolation='nearest')
#plt.show()

# %%
im3 = np.array([im_1, im_2])
print (im3.size)
print (im3.shape)
print (im_1.shape)
# Out:
# 1051560
# (2, 230, 762, 3)
# (230, 762, 3)

# %%
im_1.save('dino_shot_03.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-0303d9c1a526> in <module>()
# ----> 1 im_1.save('dino_shot_03.png')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'save'

# %%
last_time = time.time()
while(True):
    im = pyautogui.screenshot(region=(112, 178, 560, 190))
    print ('loop table {} seconds'.format(time.time() - last_time))
    last_time = time.time()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-f45110158164> in <module>()
#       3 while(True):
#       4         im = pyautogui.screenshot(region=(12, 155, 762, 230))
# ----> 5         im_p = np.array[im + im_p]
#       6         print ('loop table {} seconds'.format(time.time() - last_time))
#       7         last_time = time.time()
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %% [markdown]
# ### To make stack of four images

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-c8ec22b3e787> in <module>()
# ----> 1 import cv2
#
# ImportError: /usr/lib/x86_64-linux-gnu/libatk-1.0.so.0: undefined symbol: g_log_structured_standard

# %%
import pyscreenshot as ImageGrab

# %%
img = ImageGrab.grab(bbox=(100, 10, 600, 500)) #x, y, w, h
#img_np = np.array(img)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x490 at 0x7F48336BCE48>

# %%
print(type(img))
print (img.size)
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# (500, 490)

# %%
last_time = time.time()
while(True):
    im = ImageGrab.grab(bbox=(100, 10, 600, 500))
    print ('loop table {} seconds'.format(time.time() - last_time))
    last_time = time.time()
# Out:
# loop table 0.329547643661499 seconds
# loop table 0.27234959602355957 seconds
# loop table 0.2687370777130127 seconds
# loop table 0.27863383293151855 seconds
# loop table 0.2712078094482422 seconds
# loop table 0.2687194347381592 seconds
# loop table 0.27637147903442383 seconds
# loop table 0.2701447010040283 seconds
# loop table 0.2749340534210205 seconds
# loop table 0.27532958984375 seconds
# loop table 0.2769806385040283 seconds
# loop table 0.2613394260406494 seconds
# loop table 0.3236205577850342 seconds
# loop table 0.28530359268188477 seconds
# loop table 0.2929990291595459 seconds
# loop table 0.2779347896575928 seconds
# loop table 0.2856574058532715 seconds
# loop table 0.2767212390899658 seconds
# loop table 0.2745842933654785 seconds
# loop table 0.278947114944458 seconds
# loop table 0.28246355056762695 seconds
# loop table 0.274944543838501 seconds
# loop table 0.2825791835784912 seconds
# loop table 0.28409838676452637 seconds
# ...

# %%
x = np.array([2, 3, 1, 0])

# %%
y = np.array([[1,2.0],[0,0],(1+1j,3.)])
type(y)
print (y.shape)
print (im.shape)
# Out:
# (3, 2)
# (100, 190, 560, 3)

# %%
im_f =  np.zeros((190, 560, 3))
im = np.zeros((100, 190, 560, 3))
time.sleep(5)
for i in range(100):
    im[i] = np.array(pyautogui.screenshot(region=(20, 178, 560, 190)))

# %%
from matplotlib import pyplot as plt
plt.imshow(im[99])
plt.show()

# %% [markdown]
# time.sleep(5)
# a = pyautogui.position()
# print (a)

# %%
#np.savetxt("foo.csv", im[i], delimiter=",")
print (im[0, 0].shape)
# Out:
# (560, 3)

# %%
time.sleep(7)
im_1 = pyautogui.screenshot(region=(12, 155, 762, 230))

# %%
im_1.save('dino_shot_02.png')
