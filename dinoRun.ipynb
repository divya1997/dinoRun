# %%
from google.colab import files
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-deb28570-ff0d-495a-9214-8dc66c396afd" name="files[]" multiple disabled />
#      <output id="result-deb28570-ff0d-495a-9214-8dc66c396afd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dino_shot_02.png to dino_shot_02.png

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "dino_shot_02.png" with length 1948 bytes

# %%
a = np.array(uploaded['dino_shot_02.png'])
print (type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
cap = np.array(uploaded)

# %%
# !pip install pypng
import png
# Out:
# ...
#     100% |████████████████████████████████| 378kB 23.6MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/ed/30/6c/21dd4d267f47ea09fb57881b30fe16f7231b71bd26dea38afc
# Successfully built pypng
# ...

# %%
#f = open('ramp.png', 'wb')      # binary mode is important
w = png.Writer(255, 1, greyscale=True)
w.write(uploaded['dino_shot_02.png'], [range(256)])
#f.close()

# %%
# importing OpenCV(cv2) module 
import cv2 
  
# Save image in set directory 
# Read RGB image 
img = cv2.imread('dino_shot_02.png')  
  
# Output img with window name as 'image' 
cv2.imshow('image', img)  
  
# Maintain output window utill 
# user presses a key 
cv2.waitKey(0)         
  
# Destroying present windows on screen 
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-96f16ba6d746> in <module>()
#       6
#       7 # Output img with window name as 'image'
# ----> 8 cv2.imshow('image', img)
#       9
#      10 # Maintain output window utill
#
# error: OpenCV(3.4.3) /io/opencv/modules/highgui/src/window.cpp:356: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
